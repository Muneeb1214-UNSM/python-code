# %%
age = "25"
print(age)
# Out:
# 25

# %%
type(age)
# Out:
# str

# %%
print(int(age))
# Out:
# 25

# %%
type(age)
# Out:
# str

# %%
input("please enter your age")
# Out:
# please enter your age 70
# '70'

# %%
age = input("please enter your age")
print(age)
# Out:
# please enter your age 70
# 70

# %%
type(age)
# Out:
# str

# %%
myAge = int(age)

# %%
print(myAge)
# Out:
# 70

# %%
type(myAge)
# Out:
# int
