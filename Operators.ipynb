# %%
print(2+3) #add
print(5-5) #subtract
# Out:
# 5
# 0

# %%
print(5*5) #multiply
# Out:
# 25

# %%
print(10/2) #divide
print(15//3) #floor divide
# Out:
# 5.0
# 5

# %%
print(5 == 5) #equal too
print(7 != 6) #not equal too
print(5 > 4) #greater than equal too
print(3 < 1) #less than equal too
# Out:
# True
# True
# True
# False

# %%
print(True and False)
print(True or False)
print(not False)
# Out:
# False
# True
# True

# %%
x = 20
print(x)
x += 2
print(x) 
x -= 2
print(x)
x *= 2
print(x)
x /= 2
print(x)
# Out:
# 20
# 22
# 20
# 40
# 20.0
